# %% [markdown]
# ## Analysis on Movies

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import style

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Read the File

# %%
df = pd.read_csv(r"C:\Users\Admin\Desktop\PBI on GITHUB\github upload analysis\movies.csv")
df
# Out:
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A      142
# 1               The Godfather          1972           A      175
# 2             The Dark Knight          2008          UA      152
# 3      The Godfather: Part II          1974           A      202
# 4                12 Angry Men          1957           U       96
# ..                        ...           ...         ...      ...
# 995    Breakfast at Tiffany's          1961           A      115
# 996                     Giant          1956           G      201
# 997     From Here to Eternity          1953      Passed      118
# 998                  Lifeboat          1944         NaN       97
# 999              The 39 Steps          1935         NaN       86
#
#                         Genre  IMDB_Rating  \
# 0                       Drama          9.3
# 1                Crime, Drama          9.2
# 2        Action, Crime, Drama          9.0
# ...

# %% [markdown]
# ### Statistical information about the DF

# %%
df.describe(include = 'all')
# Out:
#        Series_Title Released_Year Certificate      Runtime  Genre  \
# count          1000          1000         899  1000.000000   1000
# unique          999           100          16          NaN    202
# top        Drishyam          2014           U          NaN  Drama
# freq              2            32         234          NaN     85
# mean            NaN           NaN         NaN   122.891000    NaN
# std             NaN           NaN         NaN    28.093671    NaN
# min             NaN           NaN         NaN    45.000000    NaN
# 25%             NaN           NaN         NaN   103.000000    NaN
# 50%             NaN           NaN         NaN   119.000000    NaN
# 75%             NaN           NaN         NaN   137.000000    NaN
# max             NaN           NaN         NaN   321.000000    NaN
#
#         IMDB_Rating                                           Overview  \
# count   1000.000000                                               1000
# ...

# %% [markdown]
# ### Checking the null values.

# %%
df.isna().sum()
# Out:
# Series_Title       0
# Released_Year      0
# Certificate      101
# Runtime            0
# Genre              0
# IMDB_Rating        0
# Overview           0
# Meta_score       157
# Director           0
# Star1              0
# Star2              0
# Star3              0
# Star4              0
# No_of_Votes        0
# Gross            169
# dtype: int64

# %% [markdown]
# ### Columns present in the data set

# %%
col_count = df.columns
col_count = pd.Series(col_count)
col_count
# Out:
# 0      Series_Title
# 1     Released_Year
# 2       Certificate
# 3           Runtime
# 4             Genre
# 5       IMDB_Rating
# 6          Overview
# 7        Meta_score
# 8          Director
# 9             Star1
# 10            Star2
# 11            Star3
# 12            Star4
# 13      No_of_Votes
# 14            Gross
# dtype: object

# %% [markdown]
# ### Getting the types of datatype

# %%
df.dtypes
# Out:
# Series_Title      object
# Released_Year     object
# Certificate       object
# Runtime            int64
# Genre             object
# IMDB_Rating      float64
# Overview          object
# Meta_score       float64
# Director          object
# Star1             object
# Star2             object
# Star3             object
# Star4             object
# No_of_Votes        int64
# Gross            float64
# dtype: object

# %% [markdown]
# ### Whole information of the dataset

# %%
df.info
# Out:
# <bound method DataFrame.info of                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A      142
# 1               The Godfather          1972           A      175
# 2             The Dark Knight          2008          UA      152
# 3      The Godfather: Part II          1974           A      202
# 4                12 Angry Men          1957           U       96
# ..                        ...           ...         ...      ...
# 995    Breakfast at Tiffany's          1961           A      115
# 996                     Giant          1956           G      201
# 997     From Here to Eternity          1953      Passed      118
# 998                  Lifeboat          1944         NaN       97
# 999              The 39 Steps          1935         NaN       86
#
#                         Genre  IMDB_Rating  \
# 0                       Drama          9.3
# 1                Crime, Drama          9.2
# ...

# %% [markdown]
# ### Variance of the Dataset.

# %%
df.var()
# Out:
# Runtime        7.892544e+02
# IMDB_Rating    7.589541e-02
# Meta_score     1.531678e+02
# No_of_Votes    1.071729e+11
# Gross          1.204507e+16
# dtype: float64

# %% [markdown]
# ### Correlation of Dataset.

# %%
corr = df.corr()
corr
# Out:
#               Runtime  IMDB_Rating  Meta_score  No_of_Votes     Gross
# Runtime      1.000000     0.243096   -0.031452     0.173264  0.139671
# IMDB_Rating  0.243096     1.000000    0.268531     0.494979  0.095923
# Meta_score  -0.031452     0.268531    1.000000    -0.018507 -0.030587
# No_of_Votes  0.173264     0.494979   -0.018507     1.000000  0.574393
# Gross        0.139671     0.095923   -0.030587     0.574393  1.000000

# %% [markdown]
# ### Getting the number of columns and row our dataset have

# %%
df.shape
# Out:
# (1000, 15)

# %% [markdown]
# ### Renaming the columns

# %%
df.rename(columns = {'Series_Title' : 'Title' ,
                    'Runtime' : 'Duration'} , inplace = True)

# %%
df.columns
# Out:
# Index(['Title', 'Released_Year', 'Certificate', 'Duration', 'Genre',
#        'IMDB_Rating', 'Overview', 'Meta_score', 'Director', 'Star1', 'Star2',
#        'Star3', 'Star4', 'No_of_Votes', 'Gross'],
#       dtype='object')

# %% [markdown]
# ### Extract the details of maximum duration of the movie

# %%
df.max()
# Out:
# Title                                  Ôkami kodomo no Ame to Yuki
# Released_Year                                                   PG
# Duration                                                       321
# Genre                                                      Western
# IMDB_Rating                                                    9.3
# Overview         Zak runs away from his care home to make his d...
# Meta_score                                                     100
# Director                                          Ömer Faruk Sorak
# Star1                                             Ömer Faruk Sorak
# Star2                                                  Özge Özberk
# Star3                                                  Zoe Saldana
# Star4                                                 Émile Vallée
# No_of_Votes                                                2343110
# Gross                                                  9.36662e+08
# dtype: object

# %% [markdown]
# ### Extract the details of minimum duration of the movie

# %%
df.min()
# Out:
# Title                                         (500) Days of Summer
# Released_Year                                                 1920
# Duration                                                        45
# Genre                                            Action, Adventure
# IMDB_Rating                                                    7.6
# Overview         "Documentary" about a man who can look and act...
# Meta_score                                                      28
# Director                                                Aamir Khan
# Star1                                                   Aamir Khan
# Star2                                                 Adesh Prasad
# Star3                                                   Aamir Khan
# Star4                                                 Aamir Bashir
# No_of_Votes                                                  25088
# Gross                                                         1305
# dtype: object

# %% [markdown]
# ### Total Gross of the movies

# %%
df['Gross'].max()
# Out:
# 936662225.0

# %% [markdown]
# ### Total mean Gross of the movies

# %%
df['Gross'].mean()
# Out:
# 68034750.87364621

# %% [markdown]
# ### Extracting the all different Genre.

# %%
df1 = df.loc[: ,"Genre"].unique()
genre = pd.Series(df1)
genre
# Out:
# 0                          Drama
# 1                   Crime, Drama
# 2           Action, Crime, Drama
# 3       Action, Adventure, Drama
# 4      Biography, Drama, History
#                  ...
# 197    Action, Adventure, Family
# 198       Action, Crime, Mystery
# 199    Animation, Drama, Romance
# 200          Drama, War, Western
# 201       Adventure, Comedy, War
# Length: 202, dtype: object

# %% [markdown]
# ### Extracting results on the basis of different genre.

# %%
genre = df.groupby('Genre').mean()
genre
# Out:
#                                 Duration  IMDB_Rating  Meta_score  \
# Genre
# Action, Adventure             127.800000     8.180000   71.800000
# Action, Adventure, Biography   95.000000     7.900000         NaN
# Action, Adventure, Comedy     131.000000     7.910000   66.857143
# Action, Adventure, Crime      113.000000     7.600000         NaN
# Action, Adventure, Drama      154.071429     8.150000   80.461538
# ...                                  ...          ...         ...
# Mystery, Romance, Thriller    128.000000     8.300000  100.000000
# Mystery, Sci-Fi, Thriller     114.500000     7.800000   70.000000
# Mystery, Thriller             119.111111     7.977778   78.600000
# Thriller                      108.000000     7.800000   81.000000
# Western                       148.250000     8.350000   78.250000
#
#                                 No_of_Votes         Gross
# Genre
# Action, Adventure             925533.400000  2.295072e+08
# ...

# %% [markdown]
# ### Extracting the records of the movie which have the IMDB ratings greater than 7 and Meta Score 50.

# %%
meta = df.loc[(df['IMDB_Rating'] >=7 ) & (df['Meta_score'] >= 50)]
metascore = meta.loc[: , ['Title' ,'Duration' ,'IMDB_Rating'  ,'Meta_score', 'Genre']]
metascore.head(5)
# Out:
#                       Title  Duration  IMDB_Rating  Meta_score  \
# 0  The Shawshank Redemption       142          9.3        80.0
# 1             The Godfather       175          9.2       100.0
# 2           The Dark Knight       152          9.0        84.0
# 3    The Godfather: Part II       202          9.0        90.0
# 4              12 Angry Men        96          9.0        96.0
#
#                   Genre
# 0                 Drama
# 1          Crime, Drama
# 2  Action, Crime, Drama
# 3          Crime, Drama
# 4          Crime, Drama

# %% [markdown]
# ### Visualizing the plot for Movie of different duration which got different certificates

# %%
plt.figure(figsize=(10,6))
genre = df.loc[: , ['Certificate' ,'Title' , 'Duration']].sample(15)
sns.set_theme(style="whitegrid")
sns.barplot(x="Duration", y="Title", data=genre , hue ='Certificate' )
# Out:
# <AxesSubplot:xlabel='Duration', ylabel='Title'>

# %% [markdown]
# ### Extracting the records for the Movie Title along with its genre.

# %%
tit = df.loc[: , ['Title' , 'Genre']].head(20)
tit
# Out:
#                                                 Title  \
# 0                            The Shawshank Redemption
# 1                                       The Godfather
# 2                                     The Dark Knight
# 3                              The Godfather: Part II
# 4                                        12 Angry Men
# 5       The Lord of the Rings: The Return of the King
# 6                                        Pulp Fiction
# 7                                    Schindler's List
# 8                                           Inception
# 9                                          Fight Club
# 10  The Lord of the Rings: The Fellowship of the Ring
# 11                                       Forrest Gump
# 12                    Il buono, il brutto, il cattivo
# 13              The Lord of the Rings: The Two Towers
# 14                                         The Matrix
# 15                                         Goodfellas
# ...

# %%
fig = plt.figure(figsize=(15,8))
x=tit["Title"].to_numpy()
y=tit["Genre"].to_numpy()
plt.bar(x,y,color="y")
plt.xticks(x,rotation=45)
plt.title("Movie and the Genre")
plt.ylabel("Genre")
plt.xlabel("Title")
plt.show()

# %% [markdown]
# ### Extracting the records for the released year of the movies along with the imdb and its certificate.

# %%
Year = df.loc[: , ['Released_Year' , 'Title' , 'IMDB_Rating' , 'Certificate']].sample(20)
Year
# Out:
#     Released_Year                         Title  IMDB_Rating Certificate
# 912          2009                    Zombieland          7.6           A
# 165          1995                        Casino          8.2           A
# 815          1994                    Il postino          7.7           U
# 813          1995             A Little Princess          7.7           U
# 488          2009                    District 9          7.9           A
# 588          2013                      Le passé          7.8       PG-13
# 972          1991                  Delicatessen          7.6           R
# 950          2001            Enemy at the Gates          7.6           A
# 880          2017                      Nelyubov          7.6           R
# 652          1997                       Titanic          7.8          UA
# 896          2016            Hell or High Water          7.6           R
# 445          1953                     Stalag 17          8.0         NaN
# ...

# %% [markdown]
# ### Different certificate that the movie holds

# %%
certi = df.loc[: , 'Certificate'].unique()
certi
# Out:
# array(['A', 'UA', 'U', 'PG-13', 'R', nan, 'PG', 'G', 'Passed', 'TV-14',
#        '16', 'TV-MA', 'Unrated', 'GP', 'Approved', 'TV-PG', 'U/A'],
#       dtype=object)

# %% [markdown]
# ### Extracting the details of the actors who have worked on different movies.

# %%
stars = df.loc[: ,['Title' , 'Released_Year' , 'Star1' , 'Star2' ,'Star3' ,'Star4']]
stars
# Out:
#                         Title Released_Year              Star1  \
# 0    The Shawshank Redemption          1994        Tim Robbins
# 1               The Godfather          1972      Marlon Brando
# 2             The Dark Knight          2008     Christian Bale
# 3      The Godfather: Part II          1974          Al Pacino
# 4                12 Angry Men          1957        Henry Fonda
# ..                        ...           ...                ...
# 995    Breakfast at Tiffany's          1961     Audrey Hepburn
# 996                     Giant          1956   Elizabeth Taylor
# 997     From Here to Eternity          1953     Burt Lancaster
# 998                  Lifeboat          1944  Tallulah Bankhead
# 999              The 39 Steps          1935       Robert Donat
#
#                  Star2           Star3           Star4
# 0       Morgan Freeman      Bob Gunton  William Sadler
# 1            Al Pacino      James Caan    Diane Keaton
# ...

# %% [markdown]
# ### Extracting the result for movie who has grossed the highest.

# %%
Total_gross = df.loc[: ,['Gross' , 'Title' , 'Released_Year' ]]
Total_gross
# Out:
#            Gross                     Title Released_Year
# 0     28341469.0  The Shawshank Redemption          1994
# 1    134966411.0             The Godfather          1972
# 2    534858444.0           The Dark Knight          2008
# 3     57300000.0    The Godfather: Part II          1974
# 4      4360000.0              12 Angry Men          1957
# ..           ...                       ...           ...
# 995          NaN    Breakfast at Tiffany's          1961
# 996          NaN                     Giant          1956
# 997   30500000.0     From Here to Eternity          1953
# 998          NaN                  Lifeboat          1944
# 999          NaN              The 39 Steps          1935
#
# [1000 rows x 3 columns]

# %% [markdown]
# ### Barplot to see movie and the gross income

# %%
fig = plt.figure(figsize=(10,8))
Title_gross = df.loc[: ,['Gross' , 'Title' , 'Released_Year' ]].sample(10)
sns.barplot(x = "Gross", y= 'Title' ,data=Title_gross , palette = 'winter')
# Out:
# <AxesSubplot:xlabel='Gross', ylabel='Title'>

# %% [markdown]
# ### Replot to show the which movie has grossed the highest and with which certification.

# %%
fig = plt.figure(figsize=(10,4))
Gross_title = df.loc[: ,['Gross' , 'Title' ,'Certificate' ]].sample(20)
sns.scatterplot(x="Gross", y="Title", hue = "Certificate", data = Gross_title)
# Out:
# <AxesSubplot:xlabel='Gross', ylabel='Title'>

# %% [markdown]
# ### Plotting Voilin plot for Meta score and IMDB Ratings.

# %%
Metaimdb = df.loc[:,['Meta_score' , 'IMDB_Rating']]
Metaimdb.sample(20)
# Out:
#      Meta_score  IMDB_Rating
# 931        62.0          7.6
# 540         NaN          7.9
# 902        80.0          7.6
# 668        86.0          7.8
# 23         96.0          8.6
# 796        62.0          7.7
# 531        77.0          7.9
# 169         NaN          8.2
# 976        88.0          7.6
# 877        73.0          7.6
# 4          96.0          9.0
# 483        94.0          7.9
# 530        92.0          7.9
# 199        84.0          8.1
# 738         NaN          7.7
# 442        99.0          8.0
# 612        77.0          7.8
# 296         NaN          8.1
# 569        51.0          7.8
# 724        85.0          7.7

# %%
plt.figure(figsize= (10, 5))
sns.violinplot(x = "IMDB_Rating", y = "Meta_score" ,data=Metaimdb)
# Out:
# <AxesSubplot:xlabel='IMDB_Rating', ylabel='Meta_score'>

# %%
fig = plt.figure(figsize=(10,6))
sns.distplot(df[['IMDB_Rating', 'Meta_score']])
fig.legend(labels=['IMDB Ratings','Meta_score'])
plt.show()

# %% [markdown]
# ### Extracting records for movie and its released year.

# %%
tit_rel = df.loc[: , ['Title' , 'Released_Year' ]]
tit_rel
# Out:
#                         Title Released_Year
# 0    The Shawshank Redemption          1994
# 1               The Godfather          1972
# 2             The Dark Knight          2008
# 3      The Godfather: Part II          1974
# 4                12 Angry Men          1957
# ..                        ...           ...
# 995    Breakfast at Tiffany's          1961
# 996                     Giant          1956
# 997     From Here to Eternity          1953
# 998                  Lifeboat          1944
# 999              The 39 Steps          1935
#
# [1000 rows x 2 columns]

# %%
sns.pairplot(df)

# %%
votes = df.loc[: , ['No_of_Votes','Meta_score' , 'IMDB_Rating']]
votes
# Out:
#      No_of_Votes  Meta_score  IMDB_Rating
# 0        2343110        80.0          9.3
# 1        1620367       100.0          9.2
# 2        2303232        84.0          9.0
# 3        1129952        90.0          9.0
# 4         689845        96.0          9.0
# ..           ...         ...          ...
# 995       166544        76.0          7.6
# 996        34075        84.0          7.6
# 997        43374        85.0          7.6
# 998        26471        78.0          7.6
# 999        51853        93.0          7.6
#
# [1000 rows x 3 columns]

# %% [markdown]
# ### Visualizing the IMDB ratings on the basis of number of votes and meta score.

# %%
plt.figure(figsize = (40, 10))
sns.relplot(
    data=votes,
    x="Meta_score", y="No_of_Votes",
    hue="IMDB_Rating", palette = 'winter'
)

# %% [markdown]
# ### Extracting the records for the which movie released on which year and of how much duration.

# %%
descr = df.loc[: , ['Title' , 'Released_Year' , 'Duration' , 'IMDB_Rating']].head(10)
descr
# Out:
#                                            Title Released_Year  Duration  \
# 0                       The Shawshank Redemption          1994       142
# 1                                  The Godfather          1972       175
# 2                                The Dark Knight          2008       152
# 3                         The Godfather: Part II          1974       202
# 4                                   12 Angry Men          1957        96
# 5  The Lord of the Rings: The Return of the King          2003       201
# 6                                   Pulp Fiction          1994       154
# 7                               Schindler's List          1993       195
# 8                                      Inception          2010       148
# 9                                     Fight Club          1999       139
#
#    IMDB_Rating
# 0          9.3
# 1          9.2
# 2          9.0
# 3          9.0
# 4          9.0
# 5          8.9
# 6          8.9
# 7          8.9
# 8          8.8
# ...

# %% [markdown]
# ### Visualizing for the above extracted data.

# %%
plt.figure(figsize=(20 ,10))
sns.relplot(x="Released_Year", y="Title", kind="line", palette = 'winter' ,data=descr )
plt.xticks(rotation = 90)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7, 8],
#  [Text(0, 0, '1994'),
#   Text(1, 0, '1972'),
#   Text(2, 0, '2008'),
#   Text(3, 0, '1974'),
#   Text(4, 0, '1957'),
#   Text(5, 0, '2003'),
#   Text(6, 0, '1993'),
#   Text(7, 0, '2010'),
#   Text(8, 0, '1999')])

# %%
plt.figure(figsize = (10 , 6))
sns.pairplot(data=descr, hue="Title")

# %% [markdown]
# ### Extracting the total gross of each movie

# %%
gross =  df.loc[: , ['Title' , 'Gross' , 'Certificate']].sample(20)
gross
# Out:
#                             Title        Gross Certificate
# 615                         Taken  145000989.0           A
# 270      Kaze no tani no Naushika     495770.0           U
# 484                  The Irishman    7000000.0           R
# 357                  The Avengers  623279547.0          UA
# 394                Kôkaku Kidôtai     515905.0          UA
# 757                   Frost/Nixon   18593156.0           R
# 694            La planète sauvage     193817.0           U
# 595                  Kaze tachinu    5209580.0       PG-13
# 634                      Serenity   25514517.0       PG-13
# 760                       Flipped    1752214.0          PG
# 795                Ocean's Eleven  183417150.0          UA
# 564  The Adventures of Robin Hood    3981000.0          PG
# 150               Pan's Labyrinth   37634615.0          UA
# 573                       Dunkirk  188373161.0          UA
# 836                   After Hours   10600000.0          UA
# ...

# %% [markdown]
# ### Plotting the graph for the above extracted data

# %%
plt.figure(figsize = (10 , 6))
sns.relplot(x = "Gross", y="Title", hue="Certificate", kind="line",  data = gross)

# %% [markdown]
# ### Extracting records for the movie along  with Director

# %%
director = df.loc[: ,['Title' , 'Director']]
director
# Out:
#                         Title              Director
# 0    The Shawshank Redemption        Frank Darabont
# 1               The Godfather  Francis Ford Coppola
# 2             The Dark Knight     Christopher Nolan
# 3      The Godfather: Part II  Francis Ford Coppola
# 4                12 Angry Men          Sidney Lumet
# ..                        ...                   ...
# 995    Breakfast at Tiffany's         Blake Edwards
# 996                     Giant        George Stevens
# 997     From Here to Eternity        Fred Zinnemann
# 998                  Lifeboat      Alfred Hitchcock
# 999              The 39 Steps      Alfred Hitchcock
#
# [1000 rows x 2 columns]

# %% [markdown]
# ### Conclusion

# %% [markdown]
# As i started analysing the data, i came to know which movie on which year has made. I also got to know many interesting movies.
#
# It was nice experience while working on this data sets.

# %% [markdown]
# ### Reference

# %% [markdown]
# Talking about the refrence , i got the idea to analyze this data set from 'Kaggle.com'.
# I have uploaded its CSV file too for reference.
